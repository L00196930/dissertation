# %% [markdown]
# # BERT Pipeline (Pipeline 2)
# **Namratha Shetty · L00196930 · ATU**

# %% [markdown]
# ## Setup

# %%
# !pip -q install transformers torch scikit-learn pandas numpy tqdm kagglehub
print('Dependencies installed.')
# Out:
# Dependencies installed.

# %% [markdown]
# ## Config

# %%
SEED          = 42
CLEAN_MODE    = 'minimal'   # 'minimal' = mask block-ids + timestamps + tidy whitespace (honest to AnyLog)
                            # 'aggressive' = also strip numbers/punctuation
SAMPLE_BLOCKS   = 300       # keep this many WHOLE blocks (complete traces). Raise once it runs.
MIN_BLOCK_LINES = 6         # ignore blocks with fewer lines — need multi-line traces to reconstruct
MAX_LEN       = 64          # BERT token cap per log line (HDFS lines are short)
BATCH_SIZE    = 32
PCA_DIM       = 50          # reduce 768-d BERT vectors before fusing with time
TIME_UNIT     = 60.0        # seconds per unit in the time feature (60 = distances measured in minutes)
EPS           = 1.5         # DBSCAN radius — best cell of the Section 9 sweep
MIN_SAMPLES   = 4           # DBSCAN min points for a core (blocks have >= MIN_BLOCK_LINES lines)
TIME_WEIGHT   = 2.0         # relative weight of time vs meaning — best cell of the Section 9 sweep
EPS_GRID         = [1.4, 1.5, 1.6, 1.8, 2.0]
TIME_WEIGHT_GRID = [0.0, 1.0, 2.0, 3.0, 5.0]

import numpy as np, random
random.seed(SEED); np.random.seed(SEED)
print('Config set. CLEAN_MODE =', CLEAN_MODE, '| SAMPLE_BLOCKS =', SAMPLE_BLOCKS)
# Out:
# Config set. CLEAN_MODE = minimal | SAMPLE_BLOCKS = 300

# %% [markdown]
# ## Dataset

# %%
import os, glob
DATA_DIR = None
try:
    import kagglehub
    DATA_DIR = kagglehub.dataset_download('ayenuryrr/loghub-hdfs-hadoop-distributed-file-system-data')
    print('Downloaded to:', DATA_DIR, '\n')
except Exception as e:
    print('kagglehub download failed:', e)
    print('--> Use the manual upload cell below instead.')

def show_tree(root):
    print('Files in the dataset:')
    print('-'*70)
    for f in sorted(glob.glob(os.path.join(root, '**', '*'), recursive=True)):
        if os.path.isfile(f):
            mb = os.path.getsize(f)/1e6
            print(f'  {mb:8.2f} MB   {os.path.relpath(f, root)}')
    print('-'*70)

if DATA_DIR:
    show_tree(DATA_DIR)
# Out:
# Downloading to /root/.cache/kagglehub/datasets/ayenuryrr/loghub-hdfs-hadoop-distributed-file-system-data/3.archive...
# 100%|██████████| 1.55G/1.55G [00:21<00:00, 75.9MB/s]
# Extracting files...
# Downloaded to: /root/.cache/kagglehub/datasets/ayenuryrr/loghub-hdfs-hadoop-distributed-file-system-data/versions/3
#
# Files in the dataset:
# ----------------------------------------------------------------------
#       0.29 MB   HDFS_2k/HDFS_2k.log
#       0.41 MB   HDFS_2k/HDFS_2k.log_structured.csv
#       0.00 MB   HDFS_2k/HDFS_2k.log_templates.csv
#    1577.98 MB   HDFS_v1/HDFS.log
#       0.00 MB   HDFS_v1/README.md
#      53.10 MB   HDFS_v1/preprocessed/Event_occurrence_matrix.csv
#     125.41 MB   HDFS_v1/preprocessed/Event_traces.csv
#       0.00 MB   HDFS_v1/preprocessed/HDFS.log_templates.csv
#      52.91 MB   HDFS_v1/preprocessed/HDFS.npz
#      18.64 MB   HDFS_v1/preprocessed/anomaly_label.csv
#       0.00 MB   HDFS_v2/README.md
#     697.98 MB   HDFS_v2/node_logs/hadoop-hdfs-datanode-mesos-01.log
#     409.90 MB   HDFS_v2/node_logs/hadoop-hdfs-datanode-mesos-02.log
#     444.90 MB   HDFS_v2/node_logs/hadoop-hdfs-datanode-mesos-03.log
#     377.42 MB   HDFS_v2/node_logs/hadoop-hdfs-datanode-mesos-05.log
#     407.97 MB   HDFS_v2/node_logs/hadoop-hdfs-datanode-mesos-06.log
#     441.95 MB   HDFS_v2/node_logs/hadoop-hdfs-datanode-mesos-07.log
#     423.20 MB   HDFS_v2/node_logs/hadoop-hdfs-datanode-mesos-08.log
#     418.43 MB   HDFS_v2/node_logs/hadoop-hdfs-datanode-mesos-09.log
#     397.44 MB   HDFS_v2/node_logs/hadoop-hdfs-datanode-mesos-10.log
#     367.91 MB   HDFS_v2/node_logs/hadoop-hdfs-datanode-mesos-11.log
#     423.62 MB   HDFS_v2/node_logs/hadoop-hdfs-datanode-mesos-13.log
#     379.04 MB   HDFS_v2/node_logs/hadoop-hdfs-datanode-mesos-14.log
#     348.38 MB   HDFS_v2/node_logs/hadoop-hdfs-datanode-mesos-15.log
#     311.13 MB   HDFS_v2/node_logs/hadoop-hdfs-datanode-mesos-16.log
#     447.70 MB   HDFS_v2/node_logs/hadoop-hdfs-datanode-mesos-17.log
#     458.33 MB   HDFS_v2/node_logs/hadoop-hdfs-datanode-mesos-18.log
#     449.59 MB   HDFS_v2/node_logs/hadoop-hdfs-datanode-mesos-19.log
#     429.34 MB   HDFS_v2/node_logs/hadoop-hdfs-datanode-mesos-20.log
#     438.53 MB   HDFS_v2/node_logs/hadoop-hdfs-datanode-mesos-21.log
#     438.62 MB   HDFS_v2/node_logs/hadoop-hdfs-datanode-mesos-22.log
#     437.84 MB   HDFS_v2/node_logs/hadoop-hdfs-datanode-mesos-23.log
#     413.14 MB   HDFS_v2/node_logs/hadoop-hdfs-datanode-mesos-25.log
#     421.85 MB   HDFS_v2/node_logs/hadoop-hdfs-datanode-mesos-26.log
#     420.28 MB   HDFS_v2/node_logs/hadoop-hdfs-datanode-mesos-27.log
#     426.30 MB   HDFS_v2/node_logs/hadoop-hdfs-datanode-mesos-28.log
#     400.56 MB   HDFS_v2/node_logs/hadoop-hdfs-datanode-mesos-29.log
#     324.15 MB   HDFS_v2/node_logs/hadoop-hdfs-datanode-mesos-30.log
#     325.65 MB   HDFS_v2/node_logs/hadoop-hdfs-datanode-mesos-31.log
#      50.87 MB   HDFS_v2/node_logs/hadoop-hdfs-datanode-mesos-32.log
#    5420.48 MB   HDFS_v2/node_logs/hadoop-hdfs-namenode-mesos-01.log
#      88.37 MB   HDFS_v2/node_logs/hadoop-hdfs-secondarynamenode-mesos-01.log
#       0.00 MB   HDFS_v3_TraceBench/README.md
#       0.00 MB   HDFS_v3_TraceBench/preprocessed/data_process.py
#       0.42 MB   HDFS_v3_TraceBench/preprocessed/eventId.json
#       4.20 MB   HDFS_v3_TraceBench/preprocessed/failure_taskId.json
#     258.10 MB   HDFS_v3_TraceBench/preprocessed/failure_trace.csv
#       6.69 MB   HDFS_v3_TraceBench/preprocessed/normal_taskId.json
#    1959.39 MB   HDFS_v3_TraceBench/preprocessed/normal_trace.csv
#       0.03 MB   HDFS_v3_TraceBench/preprocessed/rowNumberResult.csv
#       1.12 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptBlk_r_00FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       7.32 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptBlk_r_00FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptBlk_r_00FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptBlk_r_00FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       1.11 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptBlk_r_01FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       7.26 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptBlk_r_01FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptBlk_r_01FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptBlk_r_01FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       0.99 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptBlk_r_02FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       6.49 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptBlk_r_02FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptBlk_r_02FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptBlk_r_02FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       1.08 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptBlk_r_03FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       7.07 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptBlk_r_03FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptBlk_r_03FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptBlk_r_03FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       1.14 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptBlk_r_04FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       7.48 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptBlk_r_04FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptBlk_r_04FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptBlk_r_04FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       1.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptBlk_r_05FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       6.80 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptBlk_r_05FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptBlk_r_05FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptBlk_r_05FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       1.10 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptBlk_r_10FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       7.27 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptBlk_r_10FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptBlk_r_10FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptBlk_r_10FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       1.17 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptBlk_r_15FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       7.92 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptBlk_r_15FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptBlk_r_15FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptBlk_r_15FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       1.27 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptBlk_r_20FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       8.77 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptBlk_r_20FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptBlk_r_20FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptBlk_r_20FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       1.20 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptBlk_r_25FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       8.44 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptBlk_r_25FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptBlk_r_25FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptBlk_r_25FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       1.14 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptBlk_r_30FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       8.26 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptBlk_r_30FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptBlk_r_30FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptBlk_r_30FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       1.15 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptBlk_r_35FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       8.52 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptBlk_r_35FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptBlk_r_35FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptBlk_r_35FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       1.07 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptBlk_r_40FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       8.09 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptBlk_r_40FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptBlk_r_40FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.05 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptBlk_r_40FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       1.01 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptBlk_r_45FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       7.64 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptBlk_r_45FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptBlk_r_45FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptBlk_r_45FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       1.12 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptBlk_r_50FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       8.53 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptBlk_r_50FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptBlk_r_50FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.05 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptBlk_r_50FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       1.10 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptMeta_r_00FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       7.20 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptMeta_r_00FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptMeta_r_00FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptMeta_r_00FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       1.06 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptMeta_r_01FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       6.96 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptMeta_r_01FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptMeta_r_01FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptMeta_r_01FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       1.11 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptMeta_r_02FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       7.39 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptMeta_r_02FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptMeta_r_02FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptMeta_r_02FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       1.07 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptMeta_r_03FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       7.15 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptMeta_r_03FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptMeta_r_03FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptMeta_r_03FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       1.09 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptMeta_r_04FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       7.32 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptMeta_r_04FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptMeta_r_04FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptMeta_r_04FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       1.18 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptMeta_r_05FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       8.05 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptMeta_r_05FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptMeta_r_05FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptMeta_r_05FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       1.10 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptMeta_r_10FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       8.22 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptMeta_r_10FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptMeta_r_10FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptMeta_r_10FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       1.17 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptMeta_r_15FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#      10.25 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptMeta_r_15FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptMeta_r_15FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptMeta_r_15FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       1.15 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptMeta_r_20FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#      10.67 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptMeta_r_20FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptMeta_r_20FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptMeta_r_20FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       1.03 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptMeta_r_25FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#      11.18 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptMeta_r_25FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptMeta_r_25FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptMeta_r_25FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       0.94 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptMeta_r_30FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#      11.83 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptMeta_r_30FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptMeta_r_30FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptMeta_r_30FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       0.78 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptMeta_r_35FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#      11.08 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptMeta_r_35FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptMeta_r_35FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptMeta_r_35FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       0.67 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptMeta_r_40FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#      10.17 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptMeta_r_40FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptMeta_r_40FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptMeta_r_40FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       0.64 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptMeta_r_45FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#      10.28 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptMeta_r_45FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptMeta_r_45FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.05 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptMeta_r_45FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       0.59 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptMeta_r_50FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       9.67 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptMeta_r_50FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptMeta_r_50FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_corruptMeta_r_50FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       1.11 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutBlk_r_01FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       7.41 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutBlk_r_01FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutBlk_r_01FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutBlk_r_01FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       1.08 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutBlk_r_02FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       7.32 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutBlk_r_02FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutBlk_r_02FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutBlk_r_02FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       1.12 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutBlk_r_03FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       7.52 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutBlk_r_03FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutBlk_r_03FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutBlk_r_03FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       1.10 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutBlk_r_04FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       7.57 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutBlk_r_04FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutBlk_r_04FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutBlk_r_04FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       1.13 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutBlk_r_05FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       7.80 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutBlk_r_05FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutBlk_r_05FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutBlk_r_05FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       1.12 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutBlk_r_10FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       9.09 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutBlk_r_10FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutBlk_r_10FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutBlk_r_10FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       1.09 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutBlk_r_15FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       9.23 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutBlk_r_15FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutBlk_r_15FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutBlk_r_15FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       1.05 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutBlk_r_20FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#      10.71 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutBlk_r_20FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutBlk_r_20FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutBlk_r_20FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       1.08 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutBlk_r_25FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#      11.19 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutBlk_r_25FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutBlk_r_25FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutBlk_r_25FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       0.92 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutBlk_r_30FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#      10.97 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutBlk_r_30FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutBlk_r_30FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutBlk_r_30FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       0.73 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutBlk_r_35FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#      10.22 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutBlk_r_35FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutBlk_r_35FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.05 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutBlk_r_35FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       0.68 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutBlk_r_40FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#      10.36 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutBlk_r_40FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutBlk_r_40FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutBlk_r_40FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       0.58 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutBlk_r_45FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       9.72 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutBlk_r_45FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutBlk_r_45FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutBlk_r_45FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       0.57 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutBlk_r_50FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       9.53 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutBlk_r_50FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutBlk_r_50FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutBlk_r_50FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       1.14 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutMeta_r_01FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       7.66 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutMeta_r_01FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutMeta_r_01FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutMeta_r_01FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       1.07 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutMeta_r_02FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       7.21 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutMeta_r_02FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutMeta_r_02FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutMeta_r_02FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       1.09 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutMeta_r_03FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       7.40 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutMeta_r_03FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutMeta_r_03FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutMeta_r_03FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       1.08 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutMeta_r_04FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       7.37 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutMeta_r_04FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutMeta_r_04FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutMeta_r_04FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       1.10 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutMeta_r_05FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       7.60 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutMeta_r_05FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutMeta_r_05FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutMeta_r_05FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       1.16 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutMeta_r_10FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       8.92 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutMeta_r_10FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutMeta_r_10FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutMeta_r_10FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       1.10 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutMeta_r_15FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       8.28 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutMeta_r_15FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutMeta_r_15FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutMeta_r_15FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       1.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutMeta_r_20FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#      10.09 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutMeta_r_20FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutMeta_r_20FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutMeta_r_20FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       0.92 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutMeta_r_25FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#      10.14 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutMeta_r_25FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutMeta_r_25FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutMeta_r_25FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       0.76 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutMeta_r_30FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       9.85 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutMeta_r_30FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutMeta_r_30FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutMeta_r_30FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       0.63 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutMeta_r_35FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       8.91 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutMeta_r_35FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutMeta_r_35FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutMeta_r_35FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       0.67 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutMeta_r_40FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#      10.13 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutMeta_r_40FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutMeta_r_40FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutMeta_r_40FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       0.62 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutMeta_r_45FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       9.34 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutMeta_r_45FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutMeta_r_45FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutMeta_r_45FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       0.57 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutMeta_r_50FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       9.26 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutMeta_r_50FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutMeta_r_50FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_cutMeta_r_50FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       1.10 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossBlk_r_01FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       7.25 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossBlk_r_01FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossBlk_r_01FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossBlk_r_01FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       1.13 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossBlk_r_02FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       7.50 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossBlk_r_02FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossBlk_r_02FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossBlk_r_02FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       1.14 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossBlk_r_03FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       7.65 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossBlk_r_03FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossBlk_r_03FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossBlk_r_03FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       1.17 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossBlk_r_04FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       7.87 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossBlk_r_04FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossBlk_r_04FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossBlk_r_04FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       1.11 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossBlk_r_05FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       7.48 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossBlk_r_05FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossBlk_r_05FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossBlk_r_05FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       1.13 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossBlk_r_10FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       8.07 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossBlk_r_10FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossBlk_r_10FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossBlk_r_10FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       1.05 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossBlk_r_15FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       8.64 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossBlk_r_15FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossBlk_r_15FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossBlk_r_15FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       1.05 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossBlk_r_20FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       9.87 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossBlk_r_20FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossBlk_r_20FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossBlk_r_20FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       0.84 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossBlk_r_25FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       8.70 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossBlk_r_25FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossBlk_r_25FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossBlk_r_25FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       0.79 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossBlk_r_30FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       9.25 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossBlk_r_30FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossBlk_r_30FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossBlk_r_30FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       0.65 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossBlk_r_35FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       9.09 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossBlk_r_35FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossBlk_r_35FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossBlk_r_35FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       0.62 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossBlk_r_40FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       8.69 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossBlk_r_40FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossBlk_r_40FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossBlk_r_40FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       0.50 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossBlk_r_45FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       7.66 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossBlk_r_45FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossBlk_r_45FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossBlk_r_45FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       0.49 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossBlk_r_50FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       7.54 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossBlk_r_50FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossBlk_r_50FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossBlk_r_50FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       1.13 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossMeta_r_01FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       7.35 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossMeta_r_01FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossMeta_r_01FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossMeta_r_01FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       1.10 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossMeta_r_02FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       7.10 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossMeta_r_02FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossMeta_r_02FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossMeta_r_02FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       1.10 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossMeta_r_03FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       7.09 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossMeta_r_03FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossMeta_r_03FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossMeta_r_03FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       1.19 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossMeta_r_04FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       7.69 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossMeta_r_04FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossMeta_r_04FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossMeta_r_04FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       1.07 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossMeta_r_05FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       6.85 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossMeta_r_05FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossMeta_r_05FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossMeta_r_05FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       1.15 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossMeta_r_10FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       7.19 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossMeta_r_10FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossMeta_r_10FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossMeta_r_10FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       1.19 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossMeta_r_15FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       7.24 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossMeta_r_15FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossMeta_r_15FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossMeta_r_15FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       1.26 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossMeta_r_20FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       7.48 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossMeta_r_20FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossMeta_r_20FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossMeta_r_20FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       1.30 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossMeta_r_25FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       7.33 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossMeta_r_25FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossMeta_r_25FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossMeta_r_25FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       1.38 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossMeta_r_30FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       7.61 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossMeta_r_30FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossMeta_r_30FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossMeta_r_30FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       1.25 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossMeta_r_35FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       6.83 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossMeta_r_35FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossMeta_r_35FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossMeta_r_35FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       1.46 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossMeta_r_40FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       7.65 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossMeta_r_40FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossMeta_r_40FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossMeta_r_40FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       1.47 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossMeta_r_45FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       7.53 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossMeta_r_45FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossMeta_r_45FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossMeta_r_45FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       1.50 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossMeta_r_50FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       7.53 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossMeta_r_50FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossMeta_r_50FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Data_lossMeta_r_50FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       1.10 MB   HDFS_v3_TraceBench/tracebench/AN_Net_disconnectDN_r_01FDN_30xC_1to19B_0to120INT_15RT_5WT/edge.csv
#       7.23 MB   HDFS_v3_TraceBench/tracebench/AN_Net_disconnectDN_r_01FDN_30xC_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Net_disconnectDN_r_01FDN_30xC_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Net_disconnectDN_r_01FDN_30xC_1to19B_0to120INT_15RT_5WT/trace.csv
#       1.04 MB   HDFS_v3_TraceBench/tracebench/AN_Net_disconnectDN_r_02FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       6.86 MB   HDFS_v3_TraceBench/tracebench/AN_Net_disconnectDN_r_02FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Net_disconnectDN_r_02FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Net_disconnectDN_r_02FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       1.04 MB   HDFS_v3_TraceBench/tracebench/AN_Net_disconnectDN_r_03FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       6.95 MB   HDFS_v3_TraceBench/tracebench/AN_Net_disconnectDN_r_03FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Net_disconnectDN_r_03FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Net_disconnectDN_r_03FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       1.05 MB   HDFS_v3_TraceBench/tracebench/AN_Net_disconnectDN_r_04FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       7.00 MB   HDFS_v3_TraceBench/tracebench/AN_Net_disconnectDN_r_04FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Net_disconnectDN_r_04FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Net_disconnectDN_r_04FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       1.06 MB   HDFS_v3_TraceBench/tracebench/AN_Net_disconnectDN_r_05FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       7.15 MB   HDFS_v3_TraceBench/tracebench/AN_Net_disconnectDN_r_05FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Net_disconnectDN_r_05FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Net_disconnectDN_r_05FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       0.96 MB   HDFS_v3_TraceBench/tracebench/AN_Net_disconnectDN_r_10FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       6.82 MB   HDFS_v3_TraceBench/tracebench/AN_Net_disconnectDN_r_10FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Net_disconnectDN_r_10FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/AN_Net_disconnectDN_r_10FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       0.87 MB   HDFS_v3_TraceBench/tracebench/AN_Net_disconnectDN_r_15FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       6.84 MB   HDFS_v3_TraceBench/tracebench/AN_Net_disconnectDN_r_15FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Net_disconnectDN_r_15FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.03 MB   HDFS_v3_TraceBench/tracebench/AN_Net_disconnectDN_r_15FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       0.73 MB   HDFS_v3_TraceBench/tracebench/AN_Net_disconnectDN_r_20FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       6.29 MB   HDFS_v3_TraceBench/tracebench/AN_Net_disconnectDN_r_20FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Net_disconnectDN_r_20FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.03 MB   HDFS_v3_TraceBench/tracebench/AN_Net_disconnectDN_r_20FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       0.52 MB   HDFS_v3_TraceBench/tracebench/AN_Net_disconnectDN_r_25FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       5.09 MB   HDFS_v3_TraceBench/tracebench/AN_Net_disconnectDN_r_25FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Net_disconnectDN_r_25FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.03 MB   HDFS_v3_TraceBench/tracebench/AN_Net_disconnectDN_r_25FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       0.38 MB   HDFS_v3_TraceBench/tracebench/AN_Net_disconnectDN_r_30FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       4.54 MB   HDFS_v3_TraceBench/tracebench/AN_Net_disconnectDN_r_30FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Net_disconnectDN_r_30FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.03 MB   HDFS_v3_TraceBench/tracebench/AN_Net_disconnectDN_r_30FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       0.31 MB   HDFS_v3_TraceBench/tracebench/AN_Net_disconnectDN_r_35FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       4.17 MB   HDFS_v3_TraceBench/tracebench/AN_Net_disconnectDN_r_35FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Net_disconnectDN_r_35FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.03 MB   HDFS_v3_TraceBench/tracebench/AN_Net_disconnectDN_r_35FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       0.22 MB   HDFS_v3_TraceBench/tracebench/AN_Net_disconnectDN_r_40FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       3.61 MB   HDFS_v3_TraceBench/tracebench/AN_Net_disconnectDN_r_40FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Net_disconnectDN_r_40FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
#       0.03 MB   HDFS_v3_TraceBench/tracebench/AN_Net_disconnectDN_r_40FDN_30C_1to19B_0to120INT_15RT_5WT/trace.csv
#       0.20 MB   HDFS_v3_TraceBench/tracebench/AN_Net_disconnectDN_r_45FDN_30C_1to19B_0to120INT_15RT_5WT/edge.csv
#       3.54 MB   HDFS_v3_TraceBench/tracebench/AN_Net_disconnectDN_r_45FDN_30C_1to19B_0to120INT_15RT_5WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/AN_Net_disconnectDN_r_45FDN_30C_1to19B_0to120INT_15RT_5WT/operation.csv
# ...
#       1.33 MB   HDFS_v3_TraceBench/tracebench/NM_CL_w_30C_1to19B_0to600INT_50RT_10WT/edge.csv
#       7.33 MB   HDFS_v3_TraceBench/tracebench/NM_CL_w_30C_1to19B_0to600INT_50RT_10WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/NM_CL_w_30C_1to19B_0to600INT_50RT_10WT/operation.csv
#       0.03 MB   HDFS_v3_TraceBench/tracebench/NM_CL_w_30C_1to19B_0to600INT_50RT_10WT/trace.csv
#       1.49 MB   HDFS_v3_TraceBench/tracebench/NM_CL_w_35C_1to19B_0to600INT_50RT_10WT/edge.csv
#       8.19 MB   HDFS_v3_TraceBench/tracebench/NM_CL_w_35C_1to19B_0to600INT_50RT_10WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/NM_CL_w_35C_1to19B_0to600INT_50RT_10WT/operation.csv
#       0.03 MB   HDFS_v3_TraceBench/tracebench/NM_CL_w_35C_1to19B_0to600INT_50RT_10WT/trace.csv
#       1.62 MB   HDFS_v3_TraceBench/tracebench/NM_CL_w_40C_1to19B_0to600INT_50RT_10WT/edge.csv
#       8.93 MB   HDFS_v3_TraceBench/tracebench/NM_CL_w_40C_1to19B_0to600INT_50RT_10WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/NM_CL_w_40C_1to19B_0to600INT_50RT_10WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/NM_CL_w_40C_1to19B_0to600INT_50RT_10WT/trace.csv
#       1.90 MB   HDFS_v3_TraceBench/tracebench/NM_CL_w_45C_1to19B_0to600INT_50RT_10WT/edge.csv
#      10.45 MB   HDFS_v3_TraceBench/tracebench/NM_CL_w_45C_1to19B_0to600INT_50RT_10WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/NM_CL_w_45C_1to19B_0to600INT_50RT_10WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/NM_CL_w_45C_1to19B_0to600INT_50RT_10WT/trace.csv
#       1.90 MB   HDFS_v3_TraceBench/tracebench/NM_CL_w_50C_1to19B_0to600INT_50RT_10WT/edge.csv
#      10.49 MB   HDFS_v3_TraceBench/tracebench/NM_CL_w_50C_1to19B_0to600INT_50RT_10WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/NM_CL_w_50C_1to19B_0to600INT_50RT_10WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/NM_CL_w_50C_1to19B_0to600INT_50RT_10WT/trace.csv
#       1.26 MB   HDFS_v3_TraceBench/tracebench/NM_DN_r_01DN_30C_1to19B_0to120INT_50RT_10WT/edge.csv
#       8.25 MB   HDFS_v3_TraceBench/tracebench/NM_DN_r_01DN_30C_1to19B_0to120INT_50RT_10WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/NM_DN_r_01DN_30C_1to19B_0to120INT_50RT_10WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/NM_DN_r_01DN_30C_1to19B_0to120INT_50RT_10WT/trace.csv
#       2.56 MB   HDFS_v3_TraceBench/tracebench/NM_DN_r_05DN_30C_1to19B_0to120INT_50RT_10WT/edge.csv
#      16.85 MB   HDFS_v3_TraceBench/tracebench/NM_DN_r_05DN_30C_1to19B_0to120INT_50RT_10WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/NM_DN_r_05DN_30C_1to19B_0to120INT_50RT_10WT/operation.csv
#       0.09 MB   HDFS_v3_TraceBench/tracebench/NM_DN_r_05DN_30C_1to19B_0to120INT_50RT_10WT/trace.csv
#       2.90 MB   HDFS_v3_TraceBench/tracebench/NM_DN_r_10DN_30C_1to19B_0to120INT_50RT_10WT/edge.csv
#      19.02 MB   HDFS_v3_TraceBench/tracebench/NM_DN_r_10DN_30C_1to19B_0to120INT_50RT_10WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/NM_DN_r_10DN_30C_1to19B_0to120INT_50RT_10WT/operation.csv
#       0.10 MB   HDFS_v3_TraceBench/tracebench/NM_DN_r_10DN_30C_1to19B_0to120INT_50RT_10WT/trace.csv
#       3.20 MB   HDFS_v3_TraceBench/tracebench/NM_DN_r_15DN_30C_1to19B_0to120INT_50RT_10WT/edge.csv
#      20.97 MB   HDFS_v3_TraceBench/tracebench/NM_DN_r_15DN_30C_1to19B_0to120INT_50RT_10WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/NM_DN_r_15DN_30C_1to19B_0to120INT_50RT_10WT/operation.csv
#       0.12 MB   HDFS_v3_TraceBench/tracebench/NM_DN_r_15DN_30C_1to19B_0to120INT_50RT_10WT/trace.csv
#       3.39 MB   HDFS_v3_TraceBench/tracebench/NM_DN_r_20DN_30C_1to19B_0to120INT_50RT_10WT/edge.csv
#      22.23 MB   HDFS_v3_TraceBench/tracebench/NM_DN_r_20DN_30C_1to19B_0to120INT_50RT_10WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/NM_DN_r_20DN_30C_1to19B_0to120INT_50RT_10WT/operation.csv
#       0.12 MB   HDFS_v3_TraceBench/tracebench/NM_DN_r_20DN_30C_1to19B_0to120INT_50RT_10WT/trace.csv
#       3.38 MB   HDFS_v3_TraceBench/tracebench/NM_DN_r_25DN_30C_1to19B_0to120INT_50RT_10WT/edge.csv
#      22.13 MB   HDFS_v3_TraceBench/tracebench/NM_DN_r_25DN_30C_1to19B_0to120INT_50RT_10WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/NM_DN_r_25DN_30C_1to19B_0to120INT_50RT_10WT/operation.csv
#       0.12 MB   HDFS_v3_TraceBench/tracebench/NM_DN_r_25DN_30C_1to19B_0to120INT_50RT_10WT/trace.csv
#       3.57 MB   HDFS_v3_TraceBench/tracebench/NM_DN_r_30DN_30C_1to19B_0to120INT_50RT_10WT/edge.csv
#      23.40 MB   HDFS_v3_TraceBench/tracebench/NM_DN_r_30DN_30C_1to19B_0to120INT_50RT_10WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/NM_DN_r_30DN_30C_1to19B_0to120INT_50RT_10WT/operation.csv
#       0.12 MB   HDFS_v3_TraceBench/tracebench/NM_DN_r_30DN_30C_1to19B_0to120INT_50RT_10WT/trace.csv
#       3.61 MB   HDFS_v3_TraceBench/tracebench/NM_DN_r_35DN_30C_1to19B_0to120INT_50RT_10WT/edge.csv
#      23.62 MB   HDFS_v3_TraceBench/tracebench/NM_DN_r_35DN_30C_1to19B_0to120INT_50RT_10WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/NM_DN_r_35DN_30C_1to19B_0to120INT_50RT_10WT/operation.csv
#       0.13 MB   HDFS_v3_TraceBench/tracebench/NM_DN_r_35DN_30C_1to19B_0to120INT_50RT_10WT/trace.csv
#       3.61 MB   HDFS_v3_TraceBench/tracebench/NM_DN_r_40DN_30C_1to19B_0to120INT_50RT_10WT/edge.csv
#      23.64 MB   HDFS_v3_TraceBench/tracebench/NM_DN_r_40DN_30C_1to19B_0to120INT_50RT_10WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/NM_DN_r_40DN_30C_1to19B_0to120INT_50RT_10WT/operation.csv
#       0.13 MB   HDFS_v3_TraceBench/tracebench/NM_DN_r_40DN_30C_1to19B_0to120INT_50RT_10WT/trace.csv
#       3.69 MB   HDFS_v3_TraceBench/tracebench/NM_DN_r_45DN_30C_1to19B_0to120INT_50RT_10WT/edge.csv
#      24.20 MB   HDFS_v3_TraceBench/tracebench/NM_DN_r_45DN_30C_1to19B_0to120INT_50RT_10WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/NM_DN_r_45DN_30C_1to19B_0to120INT_50RT_10WT/operation.csv
#       0.13 MB   HDFS_v3_TraceBench/tracebench/NM_DN_r_45DN_30C_1to19B_0to120INT_50RT_10WT/trace.csv
#       3.66 MB   HDFS_v3_TraceBench/tracebench/NM_DN_r_50DN_30C_1to19B_0to120INT_50RT_10WT/edge.csv
#      23.96 MB   HDFS_v3_TraceBench/tracebench/NM_DN_r_50DN_30C_1to19B_0to120INT_50RT_10WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/NM_DN_r_50DN_30C_1to19B_0to120INT_50RT_10WT/operation.csv
#       0.13 MB   HDFS_v3_TraceBench/tracebench/NM_DN_r_50DN_30C_1to19B_0to120INT_50RT_10WT/trace.csv
#       0.90 MB   HDFS_v3_TraceBench/tracebench/NM_DN_rw_01DN_30C_1to19B_0to120INTR_0to600INTW_50RT_10WT/edge.csv
#       6.02 MB   HDFS_v3_TraceBench/tracebench/NM_DN_rw_01DN_30C_1to19B_0to120INTR_0to600INTW_50RT_10WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/NM_DN_rw_01DN_30C_1to19B_0to120INTR_0to600INTW_50RT_10WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/NM_DN_rw_01DN_30C_1to19B_0to120INTR_0to600INTW_50RT_10WT/trace.csv
#       0.80 MB   HDFS_v3_TraceBench/tracebench/NM_DN_rw_05DN_30C_1to19B_0to120INTR_0to600INTW_50RT_10WT/edge.csv
#       4.69 MB   HDFS_v3_TraceBench/tracebench/NM_DN_rw_05DN_30C_1to19B_0to120INTR_0to600INTW_50RT_10WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/NM_DN_rw_05DN_30C_1to19B_0to120INTR_0to600INTW_50RT_10WT/operation.csv
#       0.02 MB   HDFS_v3_TraceBench/tracebench/NM_DN_rw_05DN_30C_1to19B_0to120INTR_0to600INTW_50RT_10WT/trace.csv
#       1.48 MB   HDFS_v3_TraceBench/tracebench/NM_DN_rw_10DN_30C_1to19B_0to120INTR_0to600INTW_50RT_10WT/edge.csv
#       8.75 MB   HDFS_v3_TraceBench/tracebench/NM_DN_rw_10DN_30C_1to19B_0to120INTR_0to600INTW_50RT_10WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/NM_DN_rw_10DN_30C_1to19B_0to120INTR_0to600INTW_50RT_10WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/NM_DN_rw_10DN_30C_1to19B_0to120INTR_0to600INTW_50RT_10WT/trace.csv
#       1.64 MB   HDFS_v3_TraceBench/tracebench/NM_DN_rw_15DN_30C_1to19B_0to120INTR_0to600INTW_50RT_10WT/edge.csv
#       9.74 MB   HDFS_v3_TraceBench/tracebench/NM_DN_rw_15DN_30C_1to19B_0to120INTR_0to600INTW_50RT_10WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/NM_DN_rw_15DN_30C_1to19B_0to120INTR_0to600INTW_50RT_10WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/NM_DN_rw_15DN_30C_1to19B_0to120INTR_0to600INTW_50RT_10WT/trace.csv
#       1.64 MB   HDFS_v3_TraceBench/tracebench/NM_DN_rw_20DN_30C_1to19B_0to120INTR_0to600INTW_50RT_10WT/edge.csv
#       9.76 MB   HDFS_v3_TraceBench/tracebench/NM_DN_rw_20DN_30C_1to19B_0to120INTR_0to600INTW_50RT_10WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/NM_DN_rw_20DN_30C_1to19B_0to120INTR_0to600INTW_50RT_10WT/operation.csv
#       0.04 MB   HDFS_v3_TraceBench/tracebench/NM_DN_rw_20DN_30C_1to19B_0to120INTR_0to600INTW_50RT_10WT/trace.csv
#       1.73 MB   HDFS_v3_TraceBench/tracebench/NM_DN_rw_25DN_30C_1to19B_0to120INTR_0to600INTW_50RT_10WT/edge.csv
#      10.26 MB   HDFS_v3_TraceBench/tracebench/NM_DN_rw_25DN_30C_1to19B_0to120INTR_0to600INTW_50RT_10WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/NM_DN_rw_25DN_30C_1to19B_0to120INTR_0to600INTW_50RT_10WT/operation.csv
#       0.05 MB   HDFS_v3_TraceBench/tracebench/NM_DN_rw_25DN_30C_1to19B_0to120INTR_0to600INTW_50RT_10WT/trace.csv
#       1.68 MB   HDFS_v3_TraceBench/tracebench/NM_DN_rw_30DN_30C_1to19B_0to120INTR_0to600INTW_50RT_10WT/edge.csv
#       9.89 MB   HDFS_v3_TraceBench/tracebench/NM_DN_rw_30DN_30C_1to19B_0to120INTR_0to600INTW_50RT_10WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/NM_DN_rw_30DN_30C_1to19B_0to120INTR_0to600INTW_50RT_10WT/operation.csv
#       0.05 MB   HDFS_v3_TraceBench/tracebench/NM_DN_rw_30DN_30C_1to19B_0to120INTR_0to600INTW_50RT_10WT/trace.csv
#       1.63 MB   HDFS_v3_TraceBench/tracebench/NM_DN_rw_35DN_30C_1to19B_0to120INTR_0to600INTW_50RT_10WT/edge.csv
#       9.67 MB   HDFS_v3_TraceBench/tracebench/NM_DN_rw_35DN_30C_1to19B_0to120INTR_0to600INTW_50RT_10WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/NM_DN_rw_35DN_30C_1to19B_0to120INTR_0to600INTW_50RT_10WT/operation.csv
#       0.05 MB   HDFS_v3_TraceBench/tracebench/NM_DN_rw_35DN_30C_1to19B_0to120INTR_0to600INTW_50RT_10WT/trace.csv
#       1.78 MB   HDFS_v3_TraceBench/tracebench/NM_DN_rw_40DN_30C_1to19B_0to120INTR_0to600INTW_50RT_10WT/edge.csv
#      10.58 MB   HDFS_v3_TraceBench/tracebench/NM_DN_rw_40DN_30C_1to19B_0to120INTR_0to600INTW_50RT_10WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/NM_DN_rw_40DN_30C_1to19B_0to120INTR_0to600INTW_50RT_10WT/operation.csv
#       0.05 MB   HDFS_v3_TraceBench/tracebench/NM_DN_rw_40DN_30C_1to19B_0to120INTR_0to600INTW_50RT_10WT/trace.csv
#       1.70 MB   HDFS_v3_TraceBench/tracebench/NM_DN_rw_45DN_30C_1to19B_0to120INTR_0to600INTW_50RT_10WT/edge.csv
#      10.07 MB   HDFS_v3_TraceBench/tracebench/NM_DN_rw_45DN_30C_1to19B_0to120INTR_0to600INTW_50RT_10WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/NM_DN_rw_45DN_30C_1to19B_0to120INTR_0to600INTW_50RT_10WT/operation.csv
#       0.05 MB   HDFS_v3_TraceBench/tracebench/NM_DN_rw_45DN_30C_1to19B_0to120INTR_0to600INTW_50RT_10WT/trace.csv
#       1.77 MB   HDFS_v3_TraceBench/tracebench/NM_DN_rw_50DN_30C_1to19B_0to120INTR_0to600INTW_50RT_10WT/edge.csv
#      10.48 MB   HDFS_v3_TraceBench/tracebench/NM_DN_rw_50DN_30C_1to19B_0to120INTR_0to600INTW_50RT_10WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/NM_DN_rw_50DN_30C_1to19B_0to120INTR_0to600INTW_50RT_10WT/operation.csv
#       0.05 MB   HDFS_v3_TraceBench/tracebench/NM_DN_rw_50DN_30C_1to19B_0to120INTR_0to600INTW_50RT_10WT/trace.csv
#       0.62 MB   HDFS_v3_TraceBench/tracebench/NM_DN_w_01DN_30C_1to19B_0to600INT_50RT_10WT/edge.csv
#       4.28 MB   HDFS_v3_TraceBench/tracebench/NM_DN_w_01DN_30C_1to19B_0to600INT_50RT_10WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/NM_DN_w_01DN_30C_1to19B_0to600INT_50RT_10WT/operation.csv
#       0.03 MB   HDFS_v3_TraceBench/tracebench/NM_DN_w_01DN_30C_1to19B_0to600INT_50RT_10WT/trace.csv
#       0.62 MB   HDFS_v3_TraceBench/tracebench/NM_DN_w_05DN_30C_1to19B_0to600INT_50RT_10WT/edge.csv
#       3.44 MB   HDFS_v3_TraceBench/tracebench/NM_DN_w_05DN_30C_1to19B_0to600INT_50RT_10WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/NM_DN_w_05DN_30C_1to19B_0to600INT_50RT_10WT/operation.csv
#       0.01 MB   HDFS_v3_TraceBench/tracebench/NM_DN_w_05DN_30C_1to19B_0to600INT_50RT_10WT/trace.csv
#       1.19 MB   HDFS_v3_TraceBench/tracebench/NM_DN_w_10DN_30C_1to19B_0to600INT_50RT_10WT/edge.csv
#       6.56 MB   HDFS_v3_TraceBench/tracebench/NM_DN_w_10DN_30C_1to19B_0to600INT_50RT_10WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/NM_DN_w_10DN_30C_1to19B_0to600INT_50RT_10WT/operation.csv
#       0.03 MB   HDFS_v3_TraceBench/tracebench/NM_DN_w_10DN_30C_1to19B_0to600INT_50RT_10WT/trace.csv
#       1.28 MB   HDFS_v3_TraceBench/tracebench/NM_DN_w_15DN_30C_1to19B_0to600INT_50RT_10WT/edge.csv
#       7.06 MB   HDFS_v3_TraceBench/tracebench/NM_DN_w_15DN_30C_1to19B_0to600INT_50RT_10WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/NM_DN_w_15DN_30C_1to19B_0to600INT_50RT_10WT/operation.csv
#       0.03 MB   HDFS_v3_TraceBench/tracebench/NM_DN_w_15DN_30C_1to19B_0to600INT_50RT_10WT/trace.csv
#       1.27 MB   HDFS_v3_TraceBench/tracebench/NM_DN_w_20DN_30C_1to19B_0to600INT_50RT_10WT/edge.csv
#       7.02 MB   HDFS_v3_TraceBench/tracebench/NM_DN_w_20DN_30C_1to19B_0to600INT_50RT_10WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/NM_DN_w_20DN_30C_1to19B_0to600INT_50RT_10WT/operation.csv
#       0.03 MB   HDFS_v3_TraceBench/tracebench/NM_DN_w_20DN_30C_1to19B_0to600INT_50RT_10WT/trace.csv
#       1.33 MB   HDFS_v3_TraceBench/tracebench/NM_DN_w_25DN_30C_1to19B_0to600INT_50RT_10WT/edge.csv
#       7.31 MB   HDFS_v3_TraceBench/tracebench/NM_DN_w_25DN_30C_1to19B_0to600INT_50RT_10WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/NM_DN_w_25DN_30C_1to19B_0to600INT_50RT_10WT/operation.csv
#       0.03 MB   HDFS_v3_TraceBench/tracebench/NM_DN_w_25DN_30C_1to19B_0to600INT_50RT_10WT/trace.csv
#       1.41 MB   HDFS_v3_TraceBench/tracebench/NM_DN_w_30DN_30C_1to19B_0to600INT_50RT_10WT/edge.csv
#       7.79 MB   HDFS_v3_TraceBench/tracebench/NM_DN_w_30DN_30C_1to19B_0to600INT_50RT_10WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/NM_DN_w_30DN_30C_1to19B_0to600INT_50RT_10WT/operation.csv
#       0.03 MB   HDFS_v3_TraceBench/tracebench/NM_DN_w_30DN_30C_1to19B_0to600INT_50RT_10WT/trace.csv
#       1.27 MB   HDFS_v3_TraceBench/tracebench/NM_DN_w_35DN_30C_1to19B_0to600INT_50RT_10WT/edge.csv
#       7.01 MB   HDFS_v3_TraceBench/tracebench/NM_DN_w_35DN_30C_1to19B_0to600INT_50RT_10WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/NM_DN_w_35DN_30C_1to19B_0to600INT_50RT_10WT/operation.csv
#       0.03 MB   HDFS_v3_TraceBench/tracebench/NM_DN_w_35DN_30C_1to19B_0to600INT_50RT_10WT/trace.csv
#       1.34 MB   HDFS_v3_TraceBench/tracebench/NM_DN_w_40DN_30C_1to19B_0to600INT_50RT_10WT/edge.csv
#       7.36 MB   HDFS_v3_TraceBench/tracebench/NM_DN_w_40DN_30C_1to19B_0to600INT_50RT_10WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/NM_DN_w_40DN_30C_1to19B_0to600INT_50RT_10WT/operation.csv
#       0.03 MB   HDFS_v3_TraceBench/tracebench/NM_DN_w_40DN_30C_1to19B_0to600INT_50RT_10WT/trace.csv
#       1.29 MB   HDFS_v3_TraceBench/tracebench/NM_DN_w_45DN_30C_1to19B_0to600INT_50RT_10WT/edge.csv
#       7.12 MB   HDFS_v3_TraceBench/tracebench/NM_DN_w_45DN_30C_1to19B_0to600INT_50RT_10WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/NM_DN_w_45DN_30C_1to19B_0to600INT_50RT_10WT/operation.csv
#       0.03 MB   HDFS_v3_TraceBench/tracebench/NM_DN_w_45DN_30C_1to19B_0to600INT_50RT_10WT/trace.csv
#       1.24 MB   HDFS_v3_TraceBench/tracebench/NM_DN_w_50DN_30C_1to19B_0to600INT_50RT_10WT/edge.csv
#       6.84 MB   HDFS_v3_TraceBench/tracebench/NM_DN_w_50DN_30C_1to19B_0to600INT_50RT_10WT/event.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/NM_DN_w_50DN_30C_1to19B_0to600INT_50RT_10WT/operation.csv
#       0.03 MB   HDFS_v3_TraceBench/tracebench/NM_DN_w_50DN_30C_1to19B_0to600INT_50RT_10WT/trace.csv
#       0.00 MB   HDFS_v3_TraceBench/tracebench/convert_sql_to_csv.py
# ----------------------------------------------------------------------

# %% [markdown]
# ## Load

# %%
import pandas as pd, glob, os
assert DATA_DIR is not None, 'Set DATA_DIR first (run the download or manual-upload cell).'

def find_files(patterns, exclude=('anomaly_label',)):
    hits = []
    for p in patterns:
        for h in glob.glob(os.path.join(DATA_DIR, '**', p), recursive=True):
            base = os.path.basename(h).lower()
            if os.path.isfile(h) and not any(x in base for x in exclude):
                hits.append(h)
    return sorted(set(hits), key=lambda f: -os.path.getsize(f))   # largest first

structured = find_files(['*log_structured*.csv', '*structured*.csv'])
raw_logs   = find_files(['HDFS.log', '*.log'])
def mb(f): return f'{os.path.getsize(f)/1e6:.1f} MB'
print('structured CSVs:', [(os.path.basename(f), mb(f)) for f in structured])
print('raw logs       :', [(os.path.basename(f), mb(f)) for f in raw_logs[:5]], '...')

# IMPORTANT: use the benchmark HDFS_v1/HDFS.log (block-per-trace ground truth).
# Do NOT just take the largest file — the HDFS_v2 node/namenode logs are bigger but their
# block mentions span days with identical templates, so they are NOT clean traces.
v1 = [f for f in raw_logs if os.path.basename(f) == 'HDFS.log' and 'v2' not in f.lower()]
big_structured = [f for f in structured if os.path.getsize(f)/1e6 > 5]
src = (v1 or big_structured or structured or raw_logs)
src = src[0] if src else None
assert src, 'No HDFS log/CSV found (anomaly_label.csv is NOT a log). Check the file list in Section 1.'

if os.path.getsize(src)/1e6 < 5:
    print('\n*** WARNING: chosen file is <5 MB — this looks like the 2k SAMPLE.')
    print('    The sample has ~1 line per block and CANNOT support trace reconstruction.')
    print('    Download the FULL HDFS.log (~1.5 GB) and re-run. ***')

if src.endswith('.csv'):
    df = pd.read_csv(src)
else:
    with open(src, 'r', errors='ignore') as f:
        df = pd.DataFrame({'Content': [ln.rstrip('\n') for ln in f if ln.strip()]})

print('\nUsing:', os.path.basename(src), '|', mb(src), '| shape:', df.shape)
display(df.head())
# Out:
# structured CSVs: [('HDFS_2k.log_structured.csv', '0.4 MB')]
# raw logs       : [('hadoop-hdfs-namenode-mesos-01.log', '5420.5 MB'), ('HDFS.log', '1578.0 MB'), ('hadoop-hdfs-datanode-mesos-01.log', '698.0 MB'), ('hadoop-hdfs-datanode-mesos-18.log', '458.3 MB'), ('hadoop-hdfs-datanode-mesos-19.log', '449.6 MB')] ...
#
# Using: HDFS.log | 1578.0 MB | shape: (11175629, 1)
#                                              Content
# 0  081109 203518 143 INFO dfs.DataNode$DataXceive...
# 1  081109 203518 35 INFO dfs.FSNamesystem: BLOCK*...
# 2  081109 203519 143 INFO dfs.DataNode$DataXceive...
# 3  081109 203519 145 INFO dfs.DataNode$DataXceive...
# 4  081109 203519 145 INFO dfs.DataNode$PacketResp...

# %% [markdown]
# ## Sampling

# %%
import re, numpy as np

def find_col(cands):
    low = {c.lower(): c for c in df.columns}
    for cand in cands:
        for lc, orig in low.items():
            if cand in lc: return orig
    return None

msg_col  = find_col(['content','message','log']) or df.columns[0]
date_col = find_col(['date'])
time_col = find_col(['time'])
print('message column:', msg_col, '| date:', date_col, '| time:', time_col)

work = pd.DataFrame()
work['message'] = df[msg_col].astype(str)

# --- GROUND TRUTH: the block id, extracted BEFORE cleaning ---
work['true_block'] = work['message'].str.extract(r'(blk_-?\d+)', expand=False)
work = work[work['true_block'].notna()].reset_index(drop=True)

# --- timestamp in SECONDS (real time, parsed properly — not a concatenated number) ---
def to_seconds(date_s, time_s):
    dt = pd.to_datetime(date_s.str.zfill(6) + time_s.str.zfill(6),
                        format='%y%m%d%H%M%S', errors='coerce')
    return (dt - dt.min()).dt.total_seconds()

if date_col and time_col:
    work['t'] = to_seconds(df.loc[work.index, date_col].astype(str),
                           df.loc[work.index, time_col].astype(str)).values
else:
    # raw HDFS_v1 lines start with 'yymmdd HHMMSS', e.g. '081109 203615 148 INFO ...'
    ts = work['message'].str.extract(r'^(\d{6})\s+(\d{6})')
    if ts[0].notna().mean() > 0.9:
        work['t'] = to_seconds(ts[0].astype(str), ts[1].astype(str)).values
        print('Parsed real timestamps from the log lines.')
    else:
        work['t'] = np.arange(len(work), dtype=float)   # last-resort fallback: row order
        print('WARNING: no timestamp found — falling back to row order.')
work['t'] = work['t'].ffill().fillna(0)

print('Rows with a block id:', len(work), '| distinct blocks:', work['true_block'].nunique())

# --- keep only blocks that are REAL multi-line traces ---
vc = work['true_block'].value_counts()
multi = vc[vc >= MIN_BLOCK_LINES].index
work = work[work['true_block'].isin(multi)].reset_index(drop=True)
assert len(work) > 0, (
    'No block has >= MIN_BLOCK_LINES lines. You have almost certainly loaded the 2k SAMPLE '
    'or a per-block file. Reconstruction needs multi-line traces — load the FULL HDFS.log.')
print(f'Blocks with >= {MIN_BLOCK_LINES} lines: {len(multi)}')

# --- sample WHOLE blocks (complete traces) ---
rng = np.random.default_rng(SEED)
blocks = work['true_block'].unique()
if len(blocks) > SAMPLE_BLOCKS:
    keep = rng.choice(blocks, size=SAMPLE_BLOCKS, replace=False)
    work = work[work['true_block'].isin(keep)].reset_index(drop=True)

sizes = work['true_block'].value_counts()
mean_lpb = len(work) / work['true_block'].nunique()
print(f'Working set: {len(work)} logs across {work["true_block"].nunique()} blocks')
print(f'Block size — min {sizes.min()}, median {int(sizes.median())}, max {sizes.max()}, mean {mean_lpb:.2f}')
assert mean_lpb >= 2, ('Mean lines/block < 2 — there are no multi-line traces to reconstruct. '
                       'This is the SAMPLE-data problem: load the full HDFS.log.')
display(work.head())
# Out:
# message column: Content | date: None | time: None
# Parsed real timestamps from the log lines.
# Rows with a block id: 11175629 | distinct blocks: 575061
# Blocks with >= 6 lines: 568880
# Working set: 5967 logs across 300 blocks
# Block size — min 13, median 19, max 37, mean 19.89
#                                              message  \
# 0  081109 204238 34 INFO dfs.FSNamesystem: BLOCK*...
# 1  081109 204238 417 INFO dfs.DataNode$DataXceive...
# 2  081109 204238 428 INFO dfs.DataNode$DataXceive...
# 3  081109 204239 413 INFO dfs.DataNode$DataXceive...
# 4  081109 204328 26 INFO dfs.FSNamesystem: BLOCK*...
#
#                  true_block      t
# 0  blk_-1121858602935306008  440.0
# 1  blk_-1121858602935306008  440.0
# 2  blk_-1121858602935306008  440.0
# 3  blk_-1121858602935306008  441.0
# 4  blk_-1121858602935306008  490.0

# %% [markdown]
# ### Distribution

# %%
import matplotlib.pyplot as plt
sizes = work['true_block'].value_counts().values
plt.figure(figsize=(7,4)); plt.hist(sizes, bins=min(40, len(set(sizes))))
plt.xlabel('lines per block (trace length)'); plt.ylabel('number of blocks')
plt.title('Data sanity — trace length distribution'); plt.grid(alpha=.3); plt.tight_layout(); plt.show()

# %% [markdown]
# ### Leakage

# %%
adj_same = float(np.mean(work['true_block'].values[1:] == work['true_block'].values[:-1]))
print(f'Fraction of adjacent rows sharing the same block: {adj_same:.3f}')
if adj_same > 0.5:
    print('WARNING: the log looks block-sorted. The temporal feature may inflate results.')
    print('         Report TIME_WEIGHT=0 as a baseline and/or shuffle before clustering.')
else:
    print('OK: adjacency is low, temporal proximity is not a trivial giveaway.')
# Out:
# Fraction of adjacent rows sharing the same block: 0.721
# WARNING: the log looks block-sorted. The temporal feature may inflate results.
#          Report TIME_WEIGHT=0 as a baseline and/or shuffle before clustering.

# %% [markdown]
# ## Preprocessing

# %%
def clean(text, mode=CLEAN_MODE):
    text = str(text)
    text = re.sub(r'blk_-?\d+(_\d+)?', ' ', text)      # remove the ground-truth id (+ genstamp) — prevents leakage
    text = re.sub(r'^\d{6}\s+\d{6}\s+\d+\s*', ' ', text)  # strip the leading timestamp so the
    text = re.sub(r'\d{4}-\d{2}-\d{2}[ ,:\d]*', ' ', text)  # TIME_WEIGHT=0 baseline is truly meaning-only
    if mode == 'aggressive':
        text = re.sub(r'/[\w./:-]+', ' ', text)         # paths / ip:port
        text = re.sub(r'\d+', ' ', text)                # remaining numbers
        text = re.sub(r'[^A-Za-z\s]', ' ', text)        # punctuation
    return re.sub(r'\s+', ' ', text).strip().lower()

work['clean'] = work['message'].apply(clean)
assert not work['clean'].str.contains('blk_').any(), 'Block id leaked into the cleaned text!'
display(work[['message','clean','true_block']].head(8))
# Out:
#                                              message  \
# 0  081109 204238 34 INFO dfs.FSNamesystem: BLOCK*...
# 1  081109 204238 417 INFO dfs.DataNode$DataXceive...
# 2  081109 204238 428 INFO dfs.DataNode$DataXceive...
# 3  081109 204239 413 INFO dfs.DataNode$DataXceive...
# 4  081109 204328 26 INFO dfs.FSNamesystem: BLOCK*...
# 5  081109 204328 27 INFO dfs.FSNamesystem: BLOCK*...
# 6  081109 204328 31 INFO dfs.FSNamesystem: BLOCK*...
# 7  081109 204328 414 INFO dfs.DataNode$PacketResp...
#
#                                                clean                true_block
# 0  info dfs.fsnamesystem: block* namesystem.alloc...  blk_-1121858602935306008
# 1  info dfs.datanode$dataxceiver: receiving block...  blk_-1121858602935306008
# 2  info dfs.datanode$dataxceiver: receiving block...  blk_-1121858602935306008
# 3  info dfs.datanode$dataxceiver: receiving block...  blk_-1121858602935306008
# 4  info dfs.fsnamesystem: block* namesystem.addst...  blk_-1121858602935306008
# 5  info dfs.fsnamesystem: block* namesystem.addst...  blk_-1121858602935306008
# 6  info dfs.fsnamesystem: block* namesystem.addst...  blk_-1121858602935306008
# 7  info dfs.datanode$packetresponder: packetrespo...  blk_-1121858602935306008

# %% [markdown]
# ## Embedding

# %%
import os
os.environ["HF_HUB_ENABLE_HF_TRANSFER"] = "0"
os.environ["HF_HUB_DOWNLOAD_TIMEOUT"]   = "60"
os.environ["HF_HUB_DISABLE_TELEMETRY"]  = "1"
os.environ["TOKENIZERS_PARALLELISM"]    = "false"

import torch, numpy as np, hashlib, time
from transformers import AutoTokenizer, AutoModel
from tqdm.auto import tqdm

device = 'cuda' if torch.cuda.is_available() else 'cpu'
print('Device:', device)
if device == 'cpu':
    print('WARNING: no GPU — set Runtime > Change runtime type > GPU for a big speed-up.')

MODEL_NAME = 'bert-base-uncased'

def load_bert(model_name, retries=4):
    """Download with retries. hf_hub resumes partial files between attempts;
    only wipe the cache as a final fallback."""
    for attempt in range(1, retries + 1):
        try:
            tok = AutoTokenizer.from_pretrained(model_name)
            mdl = AutoModel.from_pretrained(model_name)
            return tok, mdl
        except Exception as e:
            print(f'[attempt {attempt}/{retries}] download failed: {type(e).__name__}: {e}')
            time.sleep(5 * attempt)          # back off; next attempt resumes the partial file
    # last resort: clear the half-written cache and try one clean download
    print('Clearing Hugging Face cache and retrying once more...')
    os.system('rm -rf ~/.cache/huggingface/hub/models--bert-base-uncased')
    tok = AutoTokenizer.from_pretrained(model_name)
    mdl = AutoModel.from_pretrained(model_name)
    return tok, mdl

tokenizer, bert = load_bert(MODEL_NAME)
bert = bert.to(device).eval()
print('WordPiece example:', tokenizer.tokenize('received block terminating exception'))

# fall back to sensible defaults if the config cell wasn't run
BATCH_SIZE = globals().get('BATCH_SIZE', 32)
MAX_LEN    = globals().get('MAX_LEN', 64)

@torch.no_grad()
def embed(texts, batch_size=BATCH_SIZE, max_len=MAX_LEN):
    vecs = []
    for i in tqdm(range(0, len(texts), batch_size)):
        enc = tokenizer(texts[i:i+batch_size], padding=True, truncation=True,
                        max_length=max_len, return_tensors='pt').to(device)
        out = bert(**enc).last_hidden_state                 # (B,T,768)
        mask = enc['attention_mask'].unsqueeze(-1).float()  # (B,T,1)
        mean_pooled = (out*mask).sum(1) / mask.sum(1).clamp(min=1)   # masked mean-pooling
        vecs.append(mean_pooled.cpu().numpy())
    return np.vstack(vecs)

CLEAN_MODE = globals().get('CLEAN_MODE', 'minimal')
texts = work['clean'].tolist()
key   = hashlib.md5((CLEAN_MODE + '|' + '|'.join(texts)).encode()).hexdigest()[:10]
cache = f'emb_bert_{key}.npy'
if os.path.exists(cache):
    X = np.load(cache); print('Loaded cached embeddings:', X.shape)
else:
    X = embed(texts); np.save(cache, X); print('Embeddings:', X.shape, '(cached)')
# Out:
# Device: cuda
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B /  440MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# [transformers] BertModel LOAD REPORT from: bert-base-uncased
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# cls.seq_relationship.bias                  | UNEXPECTED |  |
# cls.predictions.transform.dense.weight     | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |  |
# cls.predictions.bias                       | UNEXPECTED |  |
# cls.predictions.transform.dense.bias       | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |  |
# cls.seq_relationship.weight                | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# WordPiece example: ['received', 'block', 'terminating', 'exception']
#   0%|          | 0/187 [00:00<?, ?it/s]
# Embeddings: (5967, 768) (cached)

# %% [markdown]
# ## Fusion

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler, normalize

def build_features(X, t, time_weight=TIME_WEIGHT, pca_dim=PCA_DIM, seed=SEED):
    Xr = PCA(n_components=min(pca_dim, X.shape[1]), random_state=seed).fit_transform(X)
    Xr = normalize(StandardScaler().fit_transform(Xr))   # unit-norm SEMANTICS ONLY (cosine-like)
    ts = np.asarray(t, float).reshape(-1, 1)
    ts = (ts - ts.min()) / TIME_UNIT                     # real time, in TIME_UNIT-second units
    return np.hstack([Xr, time_weight * ts])             # NO final normalize — it would erase time

feats_preview = build_features(X, work['t'].values)
print('Fused feature shape:', feats_preview.shape, '(', PCA_DIM, 'semantic +1 time )')
# Out:
# Fused feature shape: (5967, 51) ( 50 semantic +1 time )

# %% [markdown]
# ### Eps

# %%
from sklearn.neighbors import NearestNeighbors
import matplotlib.pyplot as plt
d, _ = NearestNeighbors(n_neighbors=MIN_SAMPLES).fit(feats_preview).kneighbors(feats_preview)
kd = np.sort(d[:, -1])
plt.figure(figsize=(7,4)); plt.plot(kd)
plt.xlabel('points (sorted)'); plt.ylabel(f'distance to {MIN_SAMPLES}th neighbour')
plt.title('k-distance plot — elbow suggests eps'); plt.grid(alpha=.3); plt.tight_layout(); plt.show()
print('Suggested eps around the 50th-90th percentile:',
      round(np.percentile(kd,50),3), 'to', round(np.percentile(kd,90),3))
# Out:
# Suggested eps around the 50th-90th percentile: 1.323 to 1.492

# %% [markdown]
# ## Clustering

# %%
import time
from sklearn.cluster import DBSCAN
from sklearn.metrics import (adjusted_rand_score, normalized_mutual_info_score,
                             homogeneity_completeness_v_measure, silhouette_score)
from sklearn.metrics.cluster import pair_confusion_matrix

def _singleton_noise(labels):
    # give each noise point its own unique cluster id (fair: unassigned != one big group)
    lab = labels.copy()
    idx = np.where(lab == -1)[0]
    if len(idx):
        start = lab.max() + 1
        lab[idx] = np.arange(start, start + len(idx))
    return lab

def run_pipeline(X, t, true_block, eps=EPS, min_samples=MIN_SAMPLES,
                 time_weight=TIME_WEIGHT, pca_dim=PCA_DIM, seed=SEED, verbose=False):
    y_true = pd.factorize(true_block)[0]
    t0 = time.time()
    feats = build_features(X, t, time_weight, pca_dim, seed)
    labels = DBSCAN(eps=eps, min_samples=min_samples, metric='euclidean').fit_predict(feats)
    runtime = time.time() - t0

    lab_eval = _singleton_noise(labels)          # noise -> singleton traces
    r = {'eps':eps, 'min_samples':min_samples, 'time_weight':time_weight,
         'n_clusters': int(len(set(labels)) - (1 if -1 in labels else 0)),
         'n_true_blocks': int(len(set(y_true))),
         'noise_frac': float((labels==-1).mean()),
         'runtime_s': round(runtime,2)}

    # headline reconstruction metrics (all logs, noise as singletons)
    r['ARI'] = adjusted_rand_score(y_true, lab_eval)
    r['NMI'] = normalized_mutual_info_score(y_true, lab_eval)
    h,c,v = homogeneity_completeness_v_measure(y_true, lab_eval)
    r['homogeneity'], r['completeness'], r['v_measure'] = h, c, v

    # pairwise confusion matrix -> precision / recall / f1
    (tn,fp),(fn,tp) = pair_confusion_matrix(y_true, lab_eval)
    prec = tp/(tp+fp) if (tp+fp) else 0.0
    rec  = tp/(tp+fn) if (tp+fn) else 0.0
    f1   = 2*prec*rec/(prec+rec) if (prec+rec) else 0.0
    r.update(pair_TP=int(tp), pair_FP=int(fp), pair_FN=int(fn), pair_TN=int(tn),
             pair_precision=prec, pair_recall=rec, pair_f1=f1)

    # supporting internal metrics (clustered points only)
    m = labels != -1
    if m.sum() > 1 and len(set(labels[m])) > 1:
        try: r['silhouette'] = float(silhouette_score(feats[m], labels[m]))
        except Exception: r['silhouette'] = float('nan')
    else:
        r['silhouette'] = float('nan')

    if verbose:
        for k,val in r.items(): print(f'  {k:16}: {val}')
    return labels, r

labels, metrics = run_pipeline(X, work['t'].values, work['true_block'], verbose=True)
work['cluster'] = labels
work['virtual_trace_id'] = ['NO_TRACE' if c==-1 else f'VTRACE_{c:05d}' for c in labels]
# Out:
#   eps             : 1.5
#   min_samples     : 4
#   time_weight     : 2.0
#   n_clusters      : 369
#   n_true_blocks   : 300
#   noise_frac      : 0.06251047427518015
#   runtime_s       : 0.76
#   ARI             : 0.21988596133696428
#   NMI             : 0.7943300891254772
#   homogeneity     : 0.7923902074349817
#   completeness    : 0.7962794923275732
#   v_measure       : 0.7943300891254771
#   pair_TP         : 42328
#   pair_FP         : 218162
#   pair_FN         : 76036
#   pair_TN         : 35262596
#   pair_precision  : 0.1624937617566893
#   pair_recall     : 0.35760873238484675
#   pair_f1         : 0.22345283407328415
#   silhouette      : 0.5476721326806824

# %% [markdown]
# ### Results

# %%
print('Pairwise confusion matrix (line-pairs):')
print(f"                same-cluster   diff-cluster")
print(f"  same-block      TP={metrics['pair_TP']:>10}   FN={metrics['pair_FN']:>10}")
print(f"  diff-block      FP={metrics['pair_FP']:>10}   TN={metrics['pair_TN']:>10}")
print(f"\n  Pairwise precision {metrics['pair_precision']:.4f} | recall {metrics['pair_recall']:.4f} | F1 {metrics['pair_f1']:.4f}")
print(f"  ARI {metrics['ARI']:.4f} | NMI {metrics['NMI']:.4f} | V-measure {metrics['v_measure']:.4f}")
print(f"  clusters found {metrics['n_clusters']} vs true blocks {metrics['n_true_blocks']} | noise {metrics['noise_frac']:.1%}")
# Out:
# Pairwise confusion matrix (line-pairs):
#                 same-cluster   diff-cluster
#   same-block      TP=     42328   FN=     76036
#   diff-block      FP=    218162   TN=  35262596
#
#   Pairwise precision 0.1625 | recall 0.3576 | F1 0.2235
#   ARI 0.2199 | NMI 0.7943 | V-measure 0.7943
#   clusters found 369 vs true blocks 300 | noise 6.3%

# %%
# Peek at reconstructed traces — one good example, plus honest purity stats
cl = work[work['cluster'] != -1]
purity = cl.groupby('cluster')['true_block'].nunique()
pure = purity[purity == 1]
print(f'Clusters found: {purity.shape[0]} | perfectly pure (1 true block): {len(pure)} '
      f'({len(pure)/max(purity.shape[0],1):.0%})')

# best example: the largest perfectly-pure cluster
if len(pure):
    best = cl[cl['cluster'].isin(pure.index)]['cluster'].value_counts().index[0]
    b = work[work.cluster == best]
    print(f"\nExample well-reconstructed trace VTRACE_{best:05d} "
          f"({len(b)} lines, true block: {b['true_block'].iloc[0]}):")
    for m in b['message'].head(8):
        print('  -', m[:140])

# worst example: the most over-merged cluster (be honest about the failure mode)
worst = purity.idxmax()
w = work[work.cluster == worst]
print(f"\nMost over-merged cluster VTRACE_{worst:05d} mixes {purity.max()} true blocks "
      f"({len(w)} lines) — typically simultaneous delete storms with identical text.")
for m in w['message'].head(3):
    print('  -', m[:140])
# Out:
# Clusters found: 369 | perfectly pure (1 true block): 252 (68%)
#
# Example well-reconstructed trace VTRACE_00017 (15 lines, true block: blk_8236385701919745468):
#   - 081109 223002 3517 WARN dfs.DataNode$DataXceiver: 10.251.111.80:50010:Got exception while serving blk_8236385701919745468 to /10.251.214.67:
#   - 081109 223005 3518 WARN dfs.DataNode$DataXceiver: 10.251.111.80:50010:Got exception while serving blk_8236385701919745468 to /10.251.42.191:
#   - 081109 223026 3470 WARN dfs.DataNode$DataXceiver: 10.250.15.198:50010:Got exception while serving blk_8236385701919745468 to /10.250.15.198:
#   - 081109 223029 3471 WARN dfs.DataNode$DataXceiver: 10.250.15.198:50010:Got exception while serving blk_8236385701919745468 to /10.251.91.84:
#   - 081109 223032 3529 WARN dfs.DataNode$DataXceiver: 10.251.111.80:50010:Got exception while serving blk_8236385701919745468 to /10.251.30.85:
#   - 081109 223036 3473 WARN dfs.DataNode$DataXceiver: 10.250.15.198:50010:Got exception while serving blk_8236385701919745468 to /10.250.9.207:
#   - 081109 223042 3532 WARN dfs.DataNode$DataXceiver: 10.251.111.80:50010:Got exception while serving blk_8236385701919745468 to /10.251.89.155:
#   - 081109 223053 3474 WARN dfs.DataNode$DataXceiver: 10.250.15.198:50010:Got exception while serving blk_8236385701919745468 to /10.251.123.20:
#
# Most over-merged cluster VTRACE_00079 mixes 56 true blocks (183 lines) — typically simultaneous delete storms with identical text.
#   - 081110 103302 19 INFO dfs.FSDataset: Deleting block blk_-6791454022618195619 file /mnt/hadoop/dfs/data/current/subdir61/blk_-679145402261819
#   - 081110 103304 18 INFO dfs.FSDataset: Deleting block blk_-8018054394832155516 file /mnt/hadoop/dfs/data/current/subdir34/blk_-801805439483215
#   - 081110 103306 19 INFO dfs.FSDataset: Deleting block blk_1246665391948977198 file /mnt/hadoop/dfs/data/current/subdir21/blk_12466653919489771

# %% [markdown]
# ## Visualisation

# %%
import matplotlib.pyplot as plt, numpy as np
# (1) metric summary bar chart
keys = ['ARI','NMI','v_measure','homogeneity','completeness','pair_f1','silhouette']
vals = [metrics.get(k, np.nan) for k in keys]
plt.figure(figsize=(9,4))
bars = plt.bar(keys, vals, color='#4C72B0')
for b,v in zip(bars, vals):
    if v==v: plt.text(b.get_x()+b.get_width()/2, v+0.02, f'{v:.2f}', ha='center', fontsize=9)
lo = min(-0.05, np.nanmin(vals)-0.05)
plt.ylim(lo, 1.08); plt.axhline(0, color='k', lw=.6); plt.ylabel('score')
plt.title('BERT pipeline — evaluation metrics'); plt.grid(axis='y', alpha=.3)
plt.tight_layout(); plt.show()

# %%
# (2) pairwise confusion matrix heatmap
cm = np.array([[metrics['pair_TP'], metrics['pair_FN']],
               [metrics['pair_FP'], metrics['pair_TN']]], float)
plt.figure(figsize=(5.2,4.2))
plt.imshow(cm, cmap='Blues')
plt.xticks([0,1], ['same cluster','diff cluster']); plt.yticks([0,1], ['same block','diff block'])
mx = cm.max() if cm.max()>0 else 1
for i in range(2):
    for j in range(2):
        plt.text(j, i, f'{int(cm[i,j]):,}', ha='center', va='center',
                 color='white' if cm[i,j] > mx/2 else 'black')
plt.title(f"Pairwise confusion  (P={metrics['pair_precision']:.2f}, R={metrics['pair_recall']:.2f}, F1={metrics['pair_f1']:.2f})")
plt.colorbar(); plt.tight_layout(); plt.show()

# %%
# (3) 2D semantic space: TRUE blocks vs RECONSTRUCTED traces
from sklearn.decomposition import PCA
emb2 = PCA(n_components=2, random_state=SEED).fit_transform(X)
sub = np.arange(len(emb2))
if len(sub) > 4000:
    sub = np.random.default_rng(SEED).choice(sub, 4000, replace=False)
E, TB, CL = emb2[sub], work['true_block'].values[sub], labels[sub]
fig, ax = plt.subplots(1, 2, figsize=(13,5))
for b in pd.Series(TB).value_counts().index[:10]:
    m = TB==b; ax[0].scatter(E[m,0], E[m,1], s=8)
ax[0].set_title('Semantic space — TRUE block (top 10)')
ax[1].scatter(E[CL==-1,0], E[CL==-1,1], s=6, c='lightgrey', label='noise')
for c in pd.Series(CL[CL!=-1]).value_counts().index[:10]:
    m = CL==c; ax[1].scatter(E[m,0], E[m,1], s=8)
ax[1].set_title('Semantic space — RECONSTRUCTED trace (top 10)')
for a in ax: a.set_xlabel('PC1'); a.set_ylabel('PC2')
ax[1].legend(fontsize=8, markerscale=2)
plt.tight_layout(); plt.show()
print('If the left and right colourings line up, the reconstruction matched the true traces.')
# Out:
# If the left and right colourings line up, the reconstruction matched the true traces.

# %%
# (4) clusters found vs true blocks + noise
fig, ax = plt.subplots(1, 2, figsize=(11,4))
ax[0].bar(['true blocks','found clusters'],
          [metrics['n_true_blocks'], metrics['n_clusters']], color=['#55A868','#4C72B0'])
ax[0].set_title('Reconstructed traces vs true blocks')
for i,v in enumerate([metrics['n_true_blocks'], metrics['n_clusters']]):
    ax[0].text(i, v, str(v), ha='center', va='bottom')
cl_sizes = pd.Series(labels[labels!=-1]).value_counts().values
tb_sizes = work['true_block'].value_counts().values
ax[1].hist(tb_sizes, bins=30, alpha=.6, label='true block sizes')
if len(cl_sizes): ax[1].hist(cl_sizes, bins=30, alpha=.6, label='cluster sizes')
ax[1].set_xlabel('lines'); ax[1].set_ylabel('count'); ax[1].set_title('Size distributions'); ax[1].legend()
plt.tight_layout(); plt.show()
print(f"Noise (unassigned) logs: {metrics['noise_frac']:.1%}")
# Out:
# Noise (unassigned) logs: 6.3%

# %% [markdown]
# ## Save

# %%
out = work[['message','t','true_block','virtual_trace_id']]
out.to_csv('reconstructed_traces_bert.csv', index=False)
print('Saved reconstructed_traces_bert.csv', out.shape)
try:
    from google.colab import files; files.download('reconstructed_traces_bert.csv')
except Exception: pass
# Out:
# Saved reconstructed_traces_bert.csv (5967, 4)

# %% [markdown]
# ## Sweep

# %%
rows = []
for eps in EPS_GRID:
    for tw in TIME_WEIGHT_GRID:
        _, r = run_pipeline(X, work['t'].values, work['true_block'], eps=eps, time_weight=tw)
        rows.append(r)
sweep = pd.DataFrame(rows)
cols = ['eps','time_weight','n_clusters','noise_frac','ARI','NMI','pair_f1','silhouette']
display(sweep[cols].round(4))
best = sweep.loc[sweep['ARI'].idxmax()]
print(f"Best ARI = {best['ARI']:.4f} at eps={best['eps']}, time_weight={best['time_weight']}")
# Out:
#     eps  time_weight  n_clusters  noise_frac     ARI     NMI  pair_f1  \
# 0   1.4          0.0           1      0.0000  0.0000  0.0000   0.0066
# 1   1.4          1.0         242      0.1875  0.1389  0.7740   0.1432
# 2   1.4          2.0         357      0.2619  0.1370  0.7666   0.1406
# 3   1.4          3.0         404      0.3032  0.1136  0.7627   0.1171
# 4   1.4          5.0         440      0.3379  0.1075  0.7683   0.1107
# 5   1.5          0.0           1      0.0000  0.0000  0.0000   0.0066
# 6   1.5          1.0         218      0.0466  0.1703  0.7873   0.1748
# 7   1.5          2.0         369      0.0625  0.2199  0.7943   0.2235
# 8   1.5          3.0         478      0.0746  0.2022  0.7906   0.2055
# 9   1.5          5.0         534      0.0913  0.1927  0.7951   0.1960
# 10  1.6          0.0           1      0.0000  0.0000  0.0000   0.0066
# 11  1.6          1.0         198      0.0442  0.1650  0.7777   0.1695
# 12  1.6          2.0         339      0.0556  0.2165  0.7940   0.2202
# 13  1.6          3.0         453      0.0647  0.2038  0.7926   0.2073
# 14  1.6          5.0         533      0.0788  0.1925  0.7935   0.1958
# 15  1.8          0.0           1      0.0000  0.0000  0.0000   0.0066
# 16  1.8          1.0         185      0.0394  0.1574  0.7687   0.1621
# 17  1.8          2.0         284      0.0535  0.2197  0.7897   0.2235
# 18  1.8          3.0         397      0.0597  0.2127  0.7930   0.2162
# 19  1.8          5.0         515      0.0724  0.1965  0.7926   0.1998
# 20  2.0          0.0           1      0.0000  0.0000  0.0000   0.0066
# 21  2.0          1.0         175      0.0362  0.1540  0.7618   0.1587
# 22  2.0          2.0         242      0.0488  0.1731  0.7911   0.1775
# 23  2.0          3.0         356      0.0558  0.2111  0.7926   0.2148
# 24  2.0          5.0         495      0.0652  0.1993  0.7916   0.2026
#
#     silhouette
# 0          NaN
# 1       0.5363
# 2       0.5366
# 3       0.5569
# 4       0.6142
# 5          NaN
# 6       0.5529
# 7       0.5477
# 8       0.4934
# 9       0.5757
# 10         NaN
# 11      0.5818
# 12      0.5757
# 13      0.5384
# 14      0.5801
# 15         NaN
# 16      0.5932
# 17      0.6264
# 18      0.6110
# 19      0.5958
# 20         NaN
# 21      0.6037
# 22      0.6512
# 23      0.6345
# 24      0.6108
# Best ARI = 0.2199 at eps=1.5, time_weight=2.0

# %%
# ARI vs eps, one line per time_weight
import matplotlib.pyplot as plt
plt.figure(figsize=(7,4))
for tw in TIME_WEIGHT_GRID:
    s = sweep[sweep.time_weight==tw].sort_values('eps')
    plt.plot(s['eps'], s['ARI'], marker='o', label=f'time_weight={tw}')
plt.xlabel('DBSCAN eps'); plt.ylabel('ARI'); plt.title('BERT pipeline — ARI sensitivity')
plt.legend(); plt.grid(alpha=.3); plt.tight_layout(); plt.show()

# %%
# ARI heatmap over the eps x time_weight grid
piv = sweep.pivot(index='time_weight', columns='eps', values='ARI')
plt.figure(figsize=(7,4))
plt.imshow(piv.values, aspect='auto', cmap='viridis', origin='lower')
plt.xticks(range(len(piv.columns)), piv.columns); plt.yticks(range(len(piv.index)), piv.index)
plt.xlabel('eps'); plt.ylabel('time_weight'); plt.title('ARI over the sweep grid')
for i in range(piv.shape[0]):
    for j in range(piv.shape[1]):
        plt.text(j, i, f'{piv.values[i,j]:.2f}', ha='center', va='center',
                 color='white' if piv.values[i,j] < np.nanmax(piv.values)/2 else 'black', fontsize=8)
plt.colorbar(label='ARI'); plt.tight_layout(); plt.show()

# %% [markdown]
# ## Ablation

# %%
# Ablation — time vs meaning, eps tuned PER configuration (fair geometry for each space)
from sklearn.cluster import DBSCAN
from sklearn.metrics import adjusted_rand_score, normalized_mutual_info_score
from sklearn.metrics.cluster import pair_confusion_matrix
np.random.seed(SEED)

# same PCA -> StandardScaler -> L2-normalise treatment as build_features, split by mode
def build_mode(X_, t, mode, time_weight=TIME_WEIGHT, pca_dim=PCA_DIM, seed=SEED):
    ts = ((np.asarray(t, float) - np.min(t)) / TIME_UNIT).reshape(-1, 1)   # real time, minutes
    if mode == 'time-only':
        return ts
    Xr = PCA(n_components=min(pca_dim, X_.shape[1]), random_state=seed).fit_transform(X_)
    sem = normalize(StandardScaler().fit_transform(Xr))                    # unit-norm semantics
    if mode == 'meaning-only':
        return sem
    return np.hstack([sem, time_weight * ts])                              # combined = the pipeline

# identical metric definitions to run_pipeline (noise -> singleton clusters)
def eval_config(feats, y_true, eps):
    lab = DBSCAN(eps=eps, min_samples=MIN_SAMPLES).fit_predict(feats)
    le  = _singleton_noise(lab)
    (tn, fp), (fn, tp) = pair_confusion_matrix(y_true, le)
    p = tp/(tp+fp) if (tp+fp) else 0.0
    r = tp/(tp+fn) if (tp+fn) else 0.0
    return {'ARI': adjusted_rand_score(y_true, le),
            'NMI': normalized_mutual_info_score(y_true, le),
            'pair_f1': 2*p*r/(p+r) if (p+r) else 0.0,
            'n_clusters': int(len(set(lab)) - (1 if -1 in lab else 0)),
            'noise_frac': float((lab == -1).mean())}

# per-mode eps grids: each feature space has its own geometry, so one fixed eps is unfair
EPS_GRIDS = {
    'meaning-only': np.round(np.arange(0.20, 1.62, 0.05), 2),                 # unit-norm space (max dist 2)
    'time-only':    np.round(np.concatenate([np.arange(0.20, 1.62, 0.05),     # minutes...
                                             [2.0, 3.0, 5.0, 10.0]]), 2),     # ...plus coarse tail
    'combined':     np.round(np.arange(0.20, 2.02, 0.05), 2),
}

def tune(X_, t, y_true, model_name):
    rows = []
    for mode, grid in EPS_GRIDS.items():
        best = None
        for eps in grid:
            m = eval_config(build_mode(X_, t, mode), y_true, float(eps))
            if best is None or m['ARI'] > best['ARI']:
                best = {'model': model_name, 'mode': mode, 'best_eps': float(eps), **m}
        rows.append(best)
        print(f"  {model_name:9s} {mode:13s} best_eps={best['best_eps']:<5} ARI={best['ARI']:.4f}")
    return rows

y_true = pd.factorize(work['true_block'])[0]
REPRESENTATIONS = {'BERT': X}   # this notebook's embeddings

# %%
# OPTIONAL — load the OTHER representation's cached embeddings for the side-by-side
# (produced by the Word2Vec notebook on this same runtime & sample; same cache key = same data)
other_cache = f'emb_w2v_{key}.npy'
if os.path.exists(other_cache):
    REPRESENTATIONS['Word2Vec'] = np.load(other_cache)
    print('Loaded', other_cache, REPRESENTATIONS['Word2Vec'].shape)
else:
    print(f'{other_cache} not found — run the Word2Vec notebook on this runtime to enable the side-by-side.')
# Out:
# emb_w2v_6747d0ec00.npy not found — run the Word2Vec notebook on this runtime to enable the side-by-side.

# %%
# run the ablation for every loaded representation
rows = []
for name, X_ in REPRESENTATIONS.items():
    rows += tune(X_, work['t'].values, y_true, name)
ablation = pd.DataFrame(rows)[['model','mode','best_eps','ARI','NMI','pair_f1','n_clusters','noise_frac']].round(4)
display(ablation)

# grouped bar chart — ARI per mode, models side by side
import matplotlib.pyplot as plt
modes  = ['meaning-only', 'time-only', 'combined']
models = list(REPRESENTATIONS.keys())
xpos   = np.arange(len(modes)); w = 0.8 / len(models)
plt.figure(figsize=(7.5, 4))
for j, mdl in enumerate(models):
    vals = [float(ablation[(ablation.model == mdl) & (ablation['mode'] == m)]['ARI'].iloc[0]) for m in modes]
    bars = plt.bar(xpos + j*w, vals, w, label=mdl)
    for b, v in zip(bars, vals):
        plt.text(b.get_x() + b.get_width()/2, v + 0.005, f'{v:.3f}', ha='center', fontsize=9)
plt.xticks(xpos + w*(len(models)-1)/2, modes); plt.ylabel('ARI (best eps per config)')
plt.title('Ablation — contribution of each signal'); plt.legend(); plt.grid(axis='y', alpha=.3)
plt.tight_layout(); plt.show()

# plain-English verdict, computed from the numbers
CHANCE = 0.01
for mdl in models:
    g = {m: float(ablation[(ablation.model == mdl) & (ablation['mode'] == m)]['ARI'].iloc[0]) for m in modes}
    gain = g['combined'] - g['time-only']
    print(f"[{mdl}] meaning-only ARI={g['meaning-only']:.4f} | time-only ARI={g['time-only']:.4f} | combined ARI={g['combined']:.4f}")
    print(f"  -> meaning-only is {'ABOVE' if g['meaning-only'] > CHANCE else 'NOT above'} chance (~0).")
    print(f"  -> combined {'BEATS' if gain > 0.02 else 'does NOT meaningfully beat'} time-only ({gain:+.4f} ARI).")
    if gain > 0.02:
        print('  -> semantics adds measurable trace-separating signal on top of temporal proximity.')
    else:
        print('  -> temporal proximity dominates on template-heavy HDFS; the representation is not the bottleneck.')
if len(models) == 2:
    a = {m: float(ablation[(ablation.model == models[0]) & (ablation['mode'] == m)]['ARI'].iloc[0]) for m in modes}
    b = {m: float(ablation[(ablation.model == models[1]) & (ablation['mode'] == m)]['ARI'].iloc[0]) for m in modes}
    d = max(abs(a[m] - b[m]) for m in modes)
    print(f"[{models[0]} vs {models[1]}] max ARI difference across modes = {d:.4f} -> "
          + ('the representations DIFFER meaningfully.' if d > 0.02 else 'the two representations perform equivalently.'))
# Out:
#   BERT      meaning-only  best_eps=0.7   ARI=0.0020
#   BERT      time-only     best_eps=0.65  ARI=0.2076
#   BERT      combined      best_eps=1.55  ARI=0.2225
#   model          mode  best_eps     ARI     NMI  pair_f1  n_clusters  \
# 0  BERT  meaning-only      0.70  0.0020  0.5252   0.0072         441
# 1  BERT     time-only      0.65  0.2076  0.7900   0.2115         324
# 2  BERT      combined      1.55  0.2225  0.7933   0.2261         356
#
#    noise_frac
# 0      0.1233
# 1      0.0514
# 2      0.0582
# [BERT] meaning-only ARI=0.0020 | time-only ARI=0.2076 | combined ARI=0.2225
#   -> meaning-only is NOT above chance (~0).
#   -> combined does NOT meaningfully beat time-only (+0.0149 ARI).
#   -> temporal proximity dominates on template-heavy HDFS; the representation is not the bottleneck.
